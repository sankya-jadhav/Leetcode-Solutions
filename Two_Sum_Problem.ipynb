# %% [markdown]
# ### Solution

# %%
class Solution(object):
    def twoSum(self, nums, target):
        n = len(nums)
        for i in range(n):
            for j in range(i+1,n):
                if nums[i] + nums[j] == target:
                    return [i,j]

# %% [markdown]
# #### Practice

# %%
nums = [1,2,3,4]
target = 5
n = len(nums)
for i in range(n):
    for j in range(i+1,n):
        if nums[i] + nums[j] == target:
            print([i,j])
# Out:
# [0, 3]
# [1, 2]
